# %% [markdown]
# # Data Visualization
# ## Data Set: Penguins
# ## Author : Qusai Qishta
# ### Date:23/6/2021

# %% [markdown]
# ## Importing required packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Geting penguin dataset from seaborn

# %%
penguins = sns.load_dataset('penguins')
sns.set()
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.relplot(x='flipper_length_mm', y='body_mass_g' ,data=penguins)

# %%
## The following chart shows that males penguins have more body mass than female

# %%
data_grouped_by_sex = penguins.groupby('sex', as_index=False).mean()
data_grouped_by_sex
# Out:
#       sex  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0  Female       42.096970      16.425455         197.363636  3862.272727
# 1    Male       45.854762      17.891071         204.505952  4545.684524

# %% [markdown]
# ## The following chart shows gender VS BM

# %%
sns.barplot(x='sex', y='body_mass_g', data=data_grouped_by_sex).set_title('Sex VS BM')
# Out:
# Text(0.5, 1.0, 'Sex VS BM')

# %%
data_grouped_by_species = penguins.groupby('species', as_index=False).mean()
data_grouped_by_species
# Out:
#      species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0     Adelie       38.791391      18.346358         189.953642  3700.662252
# 1  Chinstrap       48.833824      18.420588         195.823529  3733.088235
# 2     Gentoo       47.504878      14.982114         217.186992  5076.016260

# %% [markdown]
# ## The following chart shows the BM for different penguin species

# %%
sns.barplot(x='species', y='body_mass_g', data=data_grouped_by_species).set_title('species VS BM')
# Out:
# Text(0.5, 1.0, 'species VS BM')

# %% [markdown]
# ## The following chart showt the flipper length in mm for different type of penguins

# %%
sns.barplot(x='species', y='flipper_length_mm', data=data_grouped_by_species).set_title('species VS flipper length')
# Out:
# Text(0.5, 1.0, 'species VS flipper length')

# %%
data_grouped_by_island = penguins.groupby('island', as_index=False).mean()
data_grouped_by_island
# Out:
#       island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0     Biscoe       45.257485      15.874850         209.706587  4716.017964
# 1      Dream       44.167742      18.344355         193.072581  3712.903226
# 2  Torgersen       38.950980      18.429412         191.196078  3706.372549

# %% [markdown]
# ## The following chart plot the average BM for all type of penguins in each island

# %%
sns.relplot(x='island', y='body_mass_g', data=data_grouped_by_island, kind='line')

# %% [markdown]
# ## bill length and depth VS BM

# %%
sns.relplot(data=penguins,x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g")

# %% [markdown]
# ## bill length and depth for each species

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
## Dataset Analysis Conclusions
- Male penguin have more BM than female
- Gentoo penguin has more BM and flipper length than other species
- penguins live in biscoe island have more BM than other species live in different places Which means it may be plentiful in food
- more BM , more bill length and less bill depth!!
- Adelie has shortest bill length and flipper length
# Out:
#   File "<ipython-input-14-a9686750dc3f>", line 2
#     - Male penguin have more BM than female
#            ^
# SyntaxError: invalid syntax
